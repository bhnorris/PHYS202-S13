# %%
g = 9.8
l = .5
th0 = 20.*pi/180

t = arange(0.,10.+0.01,.01)
theta_app = lambda t: th0*cos(sqrt(g/l)*t)
    
plot(t,theta_app(t))
show()

# %%
def deriv(theta_current,t):
    g = 9.8
    l = .5
    theta = theta_current[0]
    omega = theta_current[1]
    dtheta = omega
    domega = -(g/l)*sin(theta)
    return array([dtheta, domega])

# %%
from scipy.integrate import odeint

t = arange(0.,10.01, 0.01)

omega0 = 0.
theta_init = array([th0, omega0])

theta = odeint(deriv,theta_init,t)

# %%
theta.shape
# Out:
# (1001, 2)

# %%
plot(t, theta_app(t), 'b-', t,theta[:,0], 'r--')
show()

# %%
th0 = 50.*pi/180

theta_init = array([th0, omega0])
theta = odeint(deriv,theta_init, t)

plot(t,theta_app(t),'b-', t,theta[:,0], 'r--')
show()

# %% [markdown]
# Exercise 1
# -

# %%
th0 = 0

theta_init = array([th0, omega0])
theta = odeint(deriv,theta_init, t)

plot(t,theta_app(t),'b-', t,theta[:,0], 'r--')
th0 = pi/4

theta_init = array([th0, omega0])
theta = odeint(deriv,theta_init, t)

plot(t,theta_app(t),'b-', t,theta[:,0], 'r--')
th0 = pi/2

theta_init = array([th0, omega0])
theta = odeint(deriv,theta_init, t)

plot(t,theta_app(t),'b-', t,theta[:,0], 'r--')
th0 = 3*pi/4

theta_init = array([th0, omega0])
theta = odeint(deriv,theta_init, t)

plot(t,theta_app(t),'b-', t,theta[:,0], 'r--')
th0 = pi

theta_init = array([th0, omega0])
theta = odeint(deriv,theta_init, t)

plot(t,theta_app(t),'b-', t,theta[:,0], 'r--')
show()

# %% [markdown]
# Exercise 2
# -

# %%
th0 = .95 * pi

theta_init = array([th0, omega0])
theta = odeint(deriv,theta_init, t)

plot(t, theta[:,0])
plot(t, theta[:,1])

# %%
plot(theta[:,0],theta[:,1],'r')

# %% [markdown]
# Exercise 3
# -

# %%
theta = odeint(deriv,theta_init, t, rtol = 1e-20,atol = 1e-20)
UE = g * l * cos(theta[:,0])
KE = .5 * (l * theta[:,1])**2
E = UE + KE
#plot(t,UE)
#plot(t,KE)
plot(t,E)
# Out:
# Illegal input detected (internal error).
# Run with full_output = 1 to get quantitative information.

# %%
#help(odeint)
