# %%
from Electrostatics import *

# %%
x = 1.; y = 1.
V11 = pointPotential(x,y,1e-9,0.,0.)
print V11
x,y = meshgrid(arange(-2.,2.,0.06),arange(-2.,2.,0.06))
Vxy = pointPotential(x,y,1e-9,0.,0.)
print Vxy
# Out:
# 6.35688996287
# [[ 3.17844498  3.2264736   3.27518137 ...,  3.3080099   3.25887245
#    3.21038671]
#  [ 3.2264736   3.2767474   3.32780417 ...,  3.36225748  3.31070058
#    3.25990071]
#  [ 3.27518137  3.32780417  3.38132445 ...,  3.41748522  3.36338676
#    3.31016192]
#  ...,
#  [ 3.3080099   3.36225748  3.41748522 ...,  3.4548315   3.39896903
#    3.34406457]
#  [ 3.25887245  3.31070058  3.36338676 ...,  3.39896903  3.34573156
#    3.29332753]
#  [ 3.21038671  3.25990071  3.31016192 ...,  3.34406457  3.29332753
#    3.24331121]]

# %%
dx, dy = .06, .06
x = arange(-2, 2, dx)
y = arange(-2, 2, dy)
X,Y = meshgrid(x,y)
V =  dipolePotential(X,Y,1,1)
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection = '3d')
p = ax.plot_surface(X, Y, V, rstride = 1, cstride = 1, lw= 0, cmap= cm.Spectral)
cb = fig.colorbar(p, shrink= .5)

# %%
dx, dy = .006, .006
x = arange(-.25, .25, dx)
y = arange(-.25, .25, dy)
X,Y = meshgrid(x,y)
Vxy = pointPotential(x,y,-2e-9,0.1,-5e-4)
V =  dipolePotential(X,Y,3e-9,.1)
V1 = Vxy +V
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection = '3d')
p = ax.plot_surface(X, Y, V1, rstride = 1, cstride = 1, lw= 0, cmap= cm.Spectral)
cb = fig.colorbar(p, shrink= .5)
levels = array([8, 4, 2, 1, .5, .25, 0 , -.25, -.5, -1, -2, -4, -8])

contour(X,Y,V,levels,linewidths = 2, cmap=cm.jet)
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x10807ee60>

# %% [markdown]
# Using boolean masks for finding data
# -

# %%
theta = arange(0, 2*pi,pi/100)
plot(theta,sin(theta))

# %%
mask = ((sin(theta)>0) & (sin(theta)<.5))
plot(theta,sin(theta), theta[mask], sin(theta[mask]))

# %% [markdown]
# Interpolation
# -

# %%
theta = arange(0, 2*pi+.01, pi/10)
mask = (theta == .5)
#print mask
# Out:
# [False False False False False False False False False False False False
#  False False False False False False False False False]

# %%
newTheta = 0.5 ; newsin = 0
from scipy.interpolate import interp1d
#help(interp1d)
sininterp = interp1d(theta, sin(theta))
newsin = sininterp(newTheta)
print newsin
plot(theta,sin(theta),newTheta,newsin, 'r+',markersize=20,markeredgewidth=3)
# Out:
# 0.473922198704
# ...

# %%
thetanew = arange(0, 2*pi + 0.01,pi/30.)
sinnew = interp1d(theta, sin(theta))(thetanew)
plot(theta,sin(theta),thetanew,sinnew,'r.')

# %%
plot(thetanew,sinnew - sin(thetanew), label = 'diff btwn interp values and actual values')

# %%
sinNewC = interp1d(theta, sin(theta), kind = 'cubic')(thetanew)
subplot(2,1,1)
plot(thetanew, sinnew - sin(thetanew), thetanew, sinNewC - sin(thetanew), 'r')
subplot(2,1,2)
plot(thetanew, sinNewC - sin(thetanew), 'r')

# %% [markdown]
# Numerical Differentiation
# -

# %%
x = arange(0., 10.01, .1)
y = x**5
plot(x, y)

# %%
dy = diff(y) #y at n +1 - y at n
print len(y), len(dy)
dx = diff(x)
dydx = dy/dx
print len(dydx)
# Out:
# 101 100
# 100

# %%
plot(x, dydx)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-c3c325ab3629> in <module>()
# ----> 1 plot(x, dydx)
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    2456         ax.hold(hold)
#    2457     try:
# -> 2458         ret = ax.plot(*args, **kwargs)
#    2459         draw_if_interactive()
#    2460     finally:
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/matplotlib/axes.py in plot(self, *args, **kwargs)
#    3846         lines = []
#    3847
# -> 3848         for line in self._get_lines(*args, **kwargs):
#    3849             self.add_line(line)
#    3850             lines.append(line)
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/matplotlib/axes.py in _grab_next_args(self, *args, **kwargs)
# ...

# %%
dydx1 = zeros(y.shape, float)
dydx1[:-1] = diff(y)/diff(x)
dydx1[-1] = (y[-1] - y[-2]) / (x[-1] - x[-2])

# %% [markdown]
# $y = x^5  \frac{dy}{dx} = 5x^4$

# %%
dydx2 = 5 * x **4

# %%
plot(x, dydx1, x,dydx2)
